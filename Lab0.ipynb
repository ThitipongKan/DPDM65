# %% [markdown]
# <a href="https://colab.research.google.com/github/ThitipongKan/DPDM65/blob/main/Lab0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #กรอกข้อมูลผู้เรียน

# %% [markdown]
# ชื่อ - สกุล:

# %% [markdown]
# ชั้น:

# %% [markdown]
# เลขที่:

# %% [markdown]
# #Lab 0: Recap-Data Exploration

# %% [markdown]
# *   การสำรวจข้อมูล (Data Exploration) เป็นขั้นตอนสำคัญในกระบวนการวิเคราะห์ข้อมูล (Data science) ซึ่งช่วยให้เราเข้าใจลักษณะและโครงสร้างของข้อมูลที่มีอยู่ รวมถึงระบุปัญหาหรือข้อบกพร่องที่อาจมีในข้อมูล ขั้นตอนนี้มีเป้าหมายเพื่อเตรียมข้อมูลให้พร้อมสำหรับการวิเคราะห์เชิงลึกหรือการสร้างแบบจำลองต่อไป

# %% [markdown]
# #แบบฝึกหัด

# %% [markdown]
# เลือกชุดข้อมูลที่กำหนดให้ ดังต่อไปนี้ มา 1 ชุดข้อมูล โดยระบุค่าที่เกี่ยวข้องลงในคำสั่งสำหรับโหลดข้อมูล
# 1. ชุดข้อมูลชื่อ Penguins
# 2. ชุดข้อมูล Iris

# %%
# ชุดข้อมูลที่ 1
import seaborn as sns
import pandas as pd

#โหลดชุดข้อมูลเพนกวินจาก Seaborn
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# ชุดข้อมูลที่ 2
import seaborn as sns
import pandas as pd

iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##เมื่อเลือกชุดข้อมูลและระบุค่าในคำสั่งสำหรับโหลดชุดข้อมูลเรียบร้อยแล้ว ขอให้ดำเนินการดังต่อไปนี้

# %% [markdown]
# 1. พิจารณาชุดข้อมูลเบื้องต้น เช่น แสดงข้อมูลเบื้องต้น ตรวจสอบจำนวนและประเภทของข้อมูล ข้อมูลสถิติเบื้องต้น

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# 2. จัดเตรียมข้อมูล เช่น cleansing, transformation

# %%
df = penguins.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %% [markdown]
# 3. ทำ Data visualization เพื่อสำรวจข้อมูลเพิ่มเติม เช่น
#
#
# *   ตรวจสอบการกระจายตัวของข้อมูลเชิงตัวเลข
# *   ตรวจสอบความสัมพันธ์ระหว่างตัวแปร
# *   ตรวจจับและการจัดการค่าผิดปกติ (Outliers)
# *   อื่น ๆ

# %%
import matplotlib.pyplot as plt
plt.scatter(df['body_mass_g'], df['flipper_length_mm'], c ='green', marker = '*')
plt.title('body_mass_g vs flipper_length_mm')
plt.xlabel('body_mass_g')
plt.ylabel('flipper_length_mm')
# Out:
# Text(0, 0.5, 'flipper_length_mm')

# %%
df1 = df.drop(columns='species')

# %%
df2 = df.select_dtypes(include='number')

# %%
df2.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 4            36.7           19.3              193.0       3450.0
# 5            39.3           20.6              190.0       3650.0

# %%
corr =df2.corr()
px.imshow(corr,text_auto= True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.boxplot(df2['body_mass_g'])
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df2['body_mass_g'], kde=True)
plt.title('Distribution of Petal Length')
plt.show()
